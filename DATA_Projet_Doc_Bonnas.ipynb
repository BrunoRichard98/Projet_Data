# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df_param = pd.read_csv("parameters.csv")

# %%
df_param
# Out:
#      flight  speed  payload      altitude        date local_time route
# 0         1    4.0      0.0            25  2019-04-07      10:13    R5
# 1         2    4.0      0.0            50  2019-04-07      10:23    R5
# 2         3    6.0      0.0            25  2019-04-07      10:33    R5
# 3         4    8.0      0.0            25  2019-04-07      10:48    R5
# 4         5    4.0      0.0            25  2019-04-07      11:05    R2
# ..      ...    ...      ...           ...         ...        ...   ...
# 204     275    8.0    500.0            25  2019-10-24       9:05    R1
# 205     276   10.0    500.0            25  2019-10-24       9:32    R1
# 206     277   10.0    500.0            25  2019-10-24       9:45    R1
# 207     278   10.0    500.0  25-50-100-25  2019-10-24      10:00    R7
# 208     279   10.0      0.0  25-50-100-25  2019-10-24      10:10    R7
#
# [209 rows x 7 columns]

# %%
df_flights = pd.read_csv("flights.csv")
# Out:
# C:\Users\bonnasl\AppData\Local\Temp\ipykernel_6120\1105481560.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_flights = pd.read_csv("flights.csv")

# %%
df_flights['power'] = df_flights['battery_voltage'] * df_flights['battery_current']

df_flights
# Out:
#         flight    time  wind_speed  wind_angle  battery_voltage  \
# 0            1    0.00         0.1        12.0        24.222174
# 1            1    0.20         0.1         3.0        24.227180
# 2            1    0.30         0.1       352.0        24.225929
# 3            1    0.50         0.1       354.0        24.224678
# 4            1    0.60         0.1       359.0        24.210905
# ...        ...     ...         ...         ...              ...
# 257891     279  152.10         1.1       198.0        22.857437
# 257892     279  152.20         1.1       196.0        22.847422
# 257893     279  152.41         1.2       189.0        22.856186
# 257894     279  152.60         1.1       187.0        22.854933
# 257895     279  152.70         1.1       184.0        22.861195
#
#         battery_current  position_x  position_y  position_z  orientation_x  \
# 0              0.087470  -79.782396   40.458047  269.332402       0.001772
# ...

# %%
# variables = ['wind_speed', 'wind_angle', 'position_x', 'position_y', 'position_z', 
#              'orientation_x', 'linear_acceleration_x', 'linear_acceleration_y', 
#              'linear_acceleration_z', 'speed', 'payload', 'altitude']

# # (3 linhas, 4 colunas)
# fig, axes = plt.subplots(3, 4, figsize=(15, 10))

# fig.tight_layout(pad=5.0)

# for i, var in enumerate(variables):
#     ax = axes[i // 4, i % 4]  
#     sns.scatterplot(x=df[var], y=df['power'], ax=ax) 
#     ax.set_title(f'Relacion entre Power et {var}')
#     ax.set_xlabel(var)
#     ax.set_ylabel('Power')

# plt.show()

# %%
list_flight = list(df_flights)

list_flight
# Out:
# ['flight',
#  'time',
#  'wind_speed',
#  'wind_angle',
#  'battery_voltage',
#  'battery_current',
#  'position_x',
#  'position_y',
#  'position_z',
#  'orientation_x',
#  'orientation_y',
#  'orientation_z',
#  'orientation_w',
#  'velocity_x',
#  'velocity_y',
#  'velocity_z',
#  'angular_x',
#  'angular_y',
#  'angular_z',
#  'linear_acceleration_x',
#  'linear_acceleration_y',
#  'linear_acceleration_z',
#  'speed',
#  'payload',
#  'altitude',
#  'date',
#  'time_day',
#  'route',
#  'power']

# %%
corr_list = df_flights.corr(numeric_only=True)['power']
corr_list
# Out:
# flight                  -0.042970
# time                    -0.190578
# wind_speed               0.479005
# wind_angle               0.083061
# battery_voltage         -0.639479
# battery_current          0.997022
# position_x              -0.257301
# position_y               0.257280
# position_z               0.496799
# orientation_x           -0.181636
# orientation_y           -0.203067
# orientation_z            0.159264
# orientation_w            0.032400
# velocity_x              -0.105972
# velocity_y               0.337205
# velocity_z               0.225852
# angular_x               -0.005847
# angular_y               -0.018338
# angular_z                0.061403
# linear_acceleration_x   -0.228275
# linear_acceleration_y    0.072014
# linear_acceleration_z   -0.100247
# speed                    0.071127
# payload                  0.171903
# power                    1.000000
# Name: power, dtype: float64

# %%
df_flights.duplicated().sum()
# Out:
# 0

# %%
df_flights.isnull().sum()/len(df)
# Out:
# flight                   0.0
# time                     0.0
# wind_speed               0.0
# wind_angle               0.0
# battery_voltage          0.0
# battery_current          0.0
# position_x               0.0
# position_y               0.0
# position_z               0.0
# orientation_x            0.0
# orientation_y            0.0
# orientation_z            0.0
# orientation_w            0.0
# velocity_x               0.0
# velocity_y               0.0
# velocity_z               0.0
# angular_x                0.0
# angular_y                0.0
# angular_z                0.0
# linear_acceleration_x    0.0
# linear_acceleration_y    0.0
# linear_acceleration_z    0.0
# speed                    0.0
# payload                  0.0
# altitude                 0.0
# date                     0.0
# time_day                 0.0
# route                    0.0
# power                    0.0
# dtype: float64

# %%
df_flights['posit'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\miniconda3\envs\deep_data\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'posit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df_flights['posit'].unique()
#
# ...

# %%
columns_2_rm = ['wind_angle', 'orientation_x','orientation_y','time_day','orientation_z','orientation_w','angular_x','angular_y' ,'angular_z', 'altitude']
df = df_flights.drop(columns=columns_2_rm, axis=1)
list(df)
# Out:
# ['flight',
#  'time',
#  'wind_speed',
#  'battery_voltage',
#  'battery_current',
#  'position_x',
#  'position_y',
#  'position_z',
#  'velocity_x',
#  'velocity_y',
#  'velocity_z',
#  'linear_acceleration_x',
#  'linear_acceleration_y',
#  'linear_acceleration_z',
#  'speed',
#  'payload',
#  'date',
#  'route',
#  'power']

# %%
# Garantir que as colunas de interesse sejam numéricas
numerical_columns = ['flight', 'time', 'wind_speed', 'battery_voltage', 'battery_current', 
                     'position_x', 'position_y', 'position_z', 'velocity_x', 'velocity_y', 
                     'velocity_z', 'linear_acceleration_x', 'linear_acceleration_y', 'linear_acceleration_z', 
                     'speed', 'payload']

# Gráfico de dispersão de cada variável numérica em relação ao 'power'
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns):
    plt.subplot(4, 4, i+1)  # Dividindo em 4 linhas e 4 colunas para os gráficos
    sns.scatterplot(x=df[column], y=df['power'])
    plt.title(f'{column} vs Power')
    plt.xlabel(column)
    plt.ylabel('Power')

plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='route', y='power', data=df)
plt.title('Relação entre Route e Power')
plt.xlabel('Route')
plt.ylabel('Power')
plt.xticks(rotation=45)
plt.show()
